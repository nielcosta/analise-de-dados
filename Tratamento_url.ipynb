# %% [markdown]
# <a href="https://colab.research.google.com/github/nielcosta/analise-de-dados/blob/main/Tratamento_url.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação através de uma URL

# %%
import pandas as pd
import numpy as np

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# %%
colnames =['Compr_Sepala', 'Largura_Sepala','Compr_Petala','Largura_Petala', 'Classe' ]

# %%
iris = pd.read_csv(url, names=colnames)

# %%
iris.head()
# Out:
#    Compr_Sepala  Largura_Sepala  Compr_Petala  Largura_Petala       Classe
# 0           5.1             3.5           1.4             0.2  Iris-setosa
# 1           4.9             3.0           1.4             0.2  Iris-setosa
# 2           4.7             3.2           1.3             0.2  Iris-setosa
# 3           4.6             3.1           1.5             0.2  Iris-setosa
# 4           5.0             3.6           1.4             0.2  Iris-setosa

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
iris.shape
# Out:
# (150, 5)

# %%
len(iris.Classe)
# Out:
# 150
